# %% [markdown]
# # Confirming that your uArm is connected and ready to use.
#
# This is a good "hello world" for the uArm. This will confirm that everything is set up and ready to go. I'm including the logger functions so that you can confirm that your uArm is working as it should.
#
# * uArm must be turned on
# * uArm must be connected via USB to your machine.
# * you must be running this notebook with __Administration__ permissions.
# * you can only have one connection open at a time. Make sure to `swift.disconnect()` before switching to a different notebook.
#
# If you are able to run the uArmStudio and move the arm, then you should be good to go. However make sure that you exit uArmStudio to free up the port.

# %%
import sys
#the uArm application is inside of the parent directory, this assumes that you are runing this notebook in the `notebooks` directory
sys.path.append('..')

from uarm.wrapper import SwiftAPI
from uarm.utils.log import logger
logger.setLevel(logger.VERBOSE)

# %% [markdown]
# This next item establishes a link between the uArm and your kernel. You can only run this once as only one connection is allowed. Also, if you are running uArmStudio or any other application that connects to the arm this next line will throw an exception.
#
# if you get:
# ```
# SerialException could not open port 'COM3': PermissionError(13, 'Access is denied.', None, 5)
# ```
#
# It means that either you are not running with __administrator__ permissions or something else has already made a connection.

# %% [markdown]
# Things to troubleshoot (Windows):
# * Administrator mode
# * Open the device manager, disable the device and enable it again.
# * Restart your computer
# * Make sure that UarmStudio or any other program using the arm is closed
# * Make sure you are specifying the correct port

# %%
# Note if you are running this you will need to make sure that you run with "Administrator Permissions"
swift = SwiftAPI(port="COM5", callback_thread_pool_size=1)
# Out:
# [INFO] 2025-01-23 15:31:11 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:98]: connect COM5 success
# [DEBUG] 2025-01-23 15:31:11 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\threaded.py:64]: serial read thread start ...
# [DEBUG] 2025-01-23 15:31:11 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\swift\grammar_async.py:14]: asyncio thread start ...
# [DEBUG] 2025-01-23 15:31:11 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\swift\__init__.py:183]: serial result handle thread start ...
# [VERBOSE] 2025-01-23 15:31:12 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: angle offset:0.0000
# [VERBOSE] 2025-01-23 15:31:12 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: device name : SwiftPro
# [VERBOSE] 2025-01-23 15:31:12 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: soft ver : V4.9.0
# [VERBOSE] 2025-01-23 15:31:12 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: api ver : V4.0.5
# [VERBOSE] 2025-01-23 15:31:12 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: work mode : 0
# [VERBOSE] 2025-01-23 15:31:12 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: @1
# [VERBOSE] 2025-01-23 15:31:12 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: @5 V1
# [DEBUG] 2025-01-23 15:31:30 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\swift\__init__.py:207]: serial result handle thread exit ...

# %% [markdown]
# If you get anything but an error the device is likely connected. On mine there is a loud single **beep** from the arm when it is connected.

# %%
device_info = swift.get_device_info()
print(device_info)
swift.reset()
# Out:
# [VERBOSE] 2025-01-23 15:31:18 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\threaded.py:102]: send: COM5, b'#1 P2201\n'
# [VERBOSE] 2025-01-23 15:31:18 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\threaded.py:102]: send: COM5, b'#2 P2202\n'
# [VERBOSE] 2025-01-23 15:31:18 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: $1 ok SwiftPro
# [VERBOSE] 2025-01-23 15:31:18 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\threaded.py:102]: send: COM5, b'#3 P2203\n'
# [VERBOSE] 2025-01-23 15:31:18 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: $2 ok V3.3.1
# [VERBOSE] 2025-01-23 15:31:18 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\threaded.py:102]: send: COM5, b'#4 P2204\n'
# [VERBOSE] 2025-01-23 15:31:18 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: $3 ok V4.9.0
# [VERBOSE] 2025-01-23 15:31:18 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\threaded.py:102]: send: COM5, b'#5 P2205\n'
# [VERBOSE] 2025-01-23 15:31:18 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: $4 ok V4.0.5
# [VERBOSE] 2025-01-23 15:31:18 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: $5 ok V508CB17684B0
# {'device_type': 'SwiftPro', 'hardware_version': '3.3.1', 'firmware_version': '4.9.0', 'api_version': '4.0.5', 'device_unique': '508CB17684B0'}

# %% [markdown]
# ##  Make some small movements to confirm that it's connected

# %%
swift.set_position(x=200, y=0, z=100)
# Out:
# [VERBOSE] 2025-01-23 15:31:23 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\threaded.py:102]: send: COM5, b'#6 G0 X200.0 Y0.0 Z100.0 F5000\n'
# [VERBOSE] 2025-01-23 15:31:23 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: $6 ok

# %% [markdown]
# The arm should have moved. To test, try entering another coordinate.

# %%
swift.set_position(x=100, y=100, z=130)
# Out:
# [VERBOSE] 2025-01-23 15:31:27 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\threaded.py:102]: send: COM5, b'#7 G0 X100.0 Y100.0 Z130.0 F5000\n'
# [VERBOSE] 2025-01-23 15:31:27 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:38]: recv: $7 ok

# %% [markdown]
# ## Close the connection
#
# At the end, disconnect from the Arm so that other applications can use it.

# %%
swift.disconnect()
# Out:
# [INFO] 2025-01-23 15:31:30 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\__init__.py:50]: connection is lost
# [DEBUG] 2025-01-23 15:31:30 [c:\Users\Test\uArm-Python-SDK\notebooks\..\uarm\comm\threaded.py:96]: serial read thread exit ...
